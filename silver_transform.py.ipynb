# %%
df = spark.read.format("delta").table("sales_bronze")

df_clean = df.dropna()

df_clean.write.format("delta").mode("overwrite").saveAsTable("sales_silver")
